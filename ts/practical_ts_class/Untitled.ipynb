# %%
require(astsa)
# Out:
# Loading required package: astsa
# Warning message:
# “package ‘astsa’ was built under R version 3.5.2”

# %%
plot(jj, type='o', main='J&J quarterly EPS', ylab='Earnings', xlab='Years')
# Out:
# Plot with title “J&J quarterly EPS”

# %%
plot(flu)
# Out:
# plot without title
